# %% [markdown]
# ## Challenges 139- 145: SQLite
# ### Notebook author: Edwin Carreno Lozano
# ### Date: 19-07-2019
#
# All these exercises were taken from the book "Python by Example: Learning to Program in 150 Challenges". This book has been written by Nichola Lacey.

# %% [markdown]
# ### Challenge 139
# Statement: Create an SQL database called PhoneBook that contains a table called Names with the following data:
# ![exercise138.png](attachment:exercise138.png)

# %% [markdown]
# ### Challenge 140
# Statement: Using the PhoneBook database from program 139, write a program that will display the following menu.
# ![exercise140.png](attachment:exercise140.png)
#
# If the user selects 1, they should be able to view the entire phonebook. If they select 2, it should allow them to add a new person to the phonebook. If they select 3, it should ask them for a surname and then display only the records of people with the same surname. If
# they select 4, it should ask for an ID and then delete that record from the table. If they select 5, it should end the program. Finally, it should display a suitable message if they enter an incorrect selection from the menu. They should return to the menu after each action, until they select 5.

# %% [markdown]
# ### Challenge 141
# Statement: Create a new SQL database called BookInfo that will store a list of authors and the books they wrote. It will have two tables. The first one should be called Authors and contain the following data:
# ![exercise141a.png](attachment:exercise141a.png)
# The second should be called Books and contain the
# following data:
# ![exercise141b.png](attachment:exercise141b.png)

# %% [markdown]
# ### Challenge 142
# Statement: Using the BookInfo database from program 141, display the list of authors and their place of birth. Ask the user to enter a place of birth and then show the title, date published and author’s name for all the books by authors who were born in the location they selected.

# %% [markdown]
# ### Challenge 143
# Statement: Using the BookInfo database, ask the user to enter a year and display all the books published after that year, sorted by the year they were published.

# %% [markdown]
# ### Challenge 144
# Statement: Using the BookInfo database, ask the user for an author’s name and then save all the books by that author to a text file, with each field separated by dashes so it looks as follows:
# ![exercise144.png](attachment:exercise144.png)
# Open the text file to make sure it has worked correctly.

# %% [markdown]
# ### Challenge 145
# Statement: Create a program that displays the following screen:
# ![exercise145.png](attachment:exercise145.png)
# It should save the data to an SQL database called TestScores when the Add button is clicked. The Clear button should clear the window.
