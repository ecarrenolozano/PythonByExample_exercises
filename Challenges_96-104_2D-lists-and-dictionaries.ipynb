# %% [markdown]
# ## Challenges 96- 104: 2D Lists and Dictionaries
# ### Notebook author: Edwin Carreno Lozano
# ### Date: 19-07-2019
#
# All these exercises were taken from the book "Python by Example: Learning to Program in 150 Challenges". This book has been written by Nichola Lacey.

# %% [markdown]
# ### Challenge 096
# Statement:Create the following using a simple 2D list using the standard Python indexing:
# ![exercise96.png](attachment:exercise96.png)

# %% [markdown]
# ### Challenge 097
# Statement: Using the 2D list from program 096, ask the user to select a row and a column and display, that value.

# %% [markdown]
# ### Challenge 098
# Statement: Using the 2D list from program 096, ask the user which row they would like displayed and display just that row. Ask them to enter a new value and add it to the end of the row and display the row again.

# %% [markdown]
# ### Challenge 099
# Statement: Change your previous program to ask the user which row they
# want displayed. Display that row. Ask which column in that row they want displayed and display the value that is held there. Ask the user if they want to change the value. If they do, ask for a new value and change the data. Finally, display the whole row again.

# %% [markdown]
# ### Challenge 100
# Statement: Create the following using a 2D dictionary showing the sales each person has made in the different geographical regions:
# ![exercise100.png](attachment:exercise100.png)

# %% [markdown]
# ### Challenge 101
# Statement: Using program 100, ask the user for a name and a region. Display the relevant data. Ask the user for the name and region of data they want to change and allow them to make the alteration to the sales figure. Display the sales for all regions for the name they choose.

# %% [markdown]
# ### Challenge 102
# Statement: Ask the user to enter the name, age and shoe size for four
# people. Ask for the name of one of the people in the list and display their age and shoe size.

# %% [markdown]
# ### Challenge 103
# Statement: Adapt program 102 to display the names and ages of all the people in the list but do not show their shoe size.

# %% [markdown]
# ### Challenge 104
# Statement: After gathering the four names, ages and shoe sizes, ask the user to enter the name of the person they want to remove from
# the list. Delete this row from the data and display the other rows
# on separate lines.
